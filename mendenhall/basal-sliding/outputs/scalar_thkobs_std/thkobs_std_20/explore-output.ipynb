# %%
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset

# %%
geology = Dataset('./geology-optimized.nc')
opti = Dataset('./optimize.nc')
obs = Dataset('../../inputs/observation.nc')

# %%
geology.variables.keys()
# Out:
# dict_keys(['y', 'x', 'thkobs', 'thkobs_std', 'thkinit', 'usurfobs', 'uvelsurfobs', 'uvelsurfobs_std', 'vvelsurfobs', 'vvelsurfobs_std', 'icemaskobs', 'strflowctrl', 'arrhenius', 'slidingco', 'thk', 'usurf', 'icemask'])

# %%
opti.variables.keys()
# Out:
# dict_keys(['iterations', 'y', 'x', 'topg', 'usurf', 'thk', 'strflowctrl', 'arrhenius', 'slidingco', 'velsurf_mag', 'velsurfobs_mag', 'divflux', 'uvelbase', 'vvelbase', 'uvelsurf', 'vvelsurf'])

# %%
obs.variables.keys()
# Out:
# dict_keys(['y', 'x', 'thkobs', 'thkobs_std', 'thkinit', 'usurfobs', 'uvelsurfobs', 'uvelsurfobs_std', 'vvelsurfobs', 'vvelsurfobs_std', 'icemaskobs'])

# %%
velbase_mag = np.sqrt(opti.variables['uvelbase'][-1]**2 + opti.variables['vvelbase'][-1]**2)
im = plt.imshow(velbase_mag)
plt.colorbar(im)
plt.show()

# %%
im = plt.imshow(opti['velsurf_mag'][-1])
plt.colorbar(im)
plt.show()

# %%
im = plt.imshow(opti['thk'][-1])
plt.colorbar(im)
plt.show()

# %%
im = plt.imshow(np.where(geology['icemask'], opti['strflowctrl'][-1], np.nan), vmax = 125, vmin = 100)
plt.colorbar(im)
plt.show()
