# %%
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset

# %%
optimize = Dataset('./optimize.nc')
geology = Dataset('./geology-optimized.nc')

# %%
geology.variables.keys()
# Out:
# dict_keys(['y', 'x', 'thkobs', 'usurfobs', 'uvelsurfobs', 'vvelsurfobs', 'icemaskobs', 'strflowctrl', 'arrhenius', 'slidingco', 'thk', 'usurf', 'icemask'])

# %%
im = plt.imshow(geology['slidingco'][:], cmap = 'RdBu_r')
plt.title('Sliding coeff')
plt.colorbar(im)
plt.show()

# %%
im = plt.imshow(geology['arrhenius'][:], cmap = 'RdBu_r')
plt.title('Arrhenius coeff')
plt.colorbar(im)
plt.show()
