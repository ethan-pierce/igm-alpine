# %%
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset

# %%
optimize = Dataset('./optimize.nc')
geology = Dataset('./geology-optimized.nc')

# %%
geology.variables.keys()
# Out:
# dict_keys(['y', 'x', 'thkobs', 'usurfobs', 'uvelsurfobs', 'vvelsurfobs', 'icemaskobs', 'strflowctrl', 'arrhenius', 'slidingco', 'thk', 'usurf', 'icemask'])

# %%
im = plt.imshow(optimize['arrhenius'][-1])
plt.colorbar(im)
plt.show()

# %%
im = plt.imshow(geology['thk'][:] - geology['thkobs'][:])
plt.colorbar(im)
plt.show()

# %%
im = plt.imshow(geology['usurf'][:] - geology['usurfobs'][:])
plt.colorbar(im)
plt.show()
