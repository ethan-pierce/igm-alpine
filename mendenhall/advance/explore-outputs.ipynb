# %%
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset

# %%
ts = Dataset('ts.nc')

# %%
ts.variables.keys()
# Out:
# dict_keys(['time', 'vol', 'area'])

# %%
plt.plot(ts.variables['time'][:], ts.variables['area'][:])
plt.show()
