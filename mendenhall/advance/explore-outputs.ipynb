# %%
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset

# %%
ex = Dataset('ex.nc')
ex.variables.keys()
# Out:
# dict_keys(['time', 'y', 'x', 'topg', 'usurf', 'thk', 'smb', 'velbar_mag', 'velsurf_mag'])

# %%
ex.variables['thk'].shape
# Out:
# (2, 2590, 1721)

# %%
im = plt.imshow(ex.variables['velsurf_mag'][1,:,:])
plt.colorbar(im)
plt.show()
